# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.arange(52).reshape(13,4),
                 columns=['col1','col2','col3','col4'])

# %%
df
# Out:
#     col1  col2  col3  col4
# 0      0     1     2     3
# 1      4     5     6     7
# 2      8     9    10    11
# 3     12    13    14    15
# 4     16    17    18    19
# 5     20    21    22    23
# 6     24    25    26    27
# 7     28    29    30    31
# 8     32    33    34    35
# 9     36    37    38    39
# 10    40    41    42    43
# 11    44    45    46    47
# 12    48    49    50    51
